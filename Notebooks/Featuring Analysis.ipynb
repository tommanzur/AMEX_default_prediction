# %% [markdown]
# # AMEX Default Prediction
# ## Featuring Engineering
# * Este notebook reune el código con el que transformamos el dataset de AMEX

# %%
import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
#Cargamos el dataset de entrenamiento
train = pd.read_feather('/Users/usuario/workspace/AMEX_data/train_data.ftr')
train.head(2)
# Out:
#                                          customer_ID        S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09  0.938477
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07  0.936523
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001734  0.008728  1.006836  0.009224  0.124023  0.008774  0.004707  ...
# 1  0.005775  0.004925  1.000977  0.006153  0.126709  0.000798  0.002714  ...
#
#    D_137  D_138     D_139     D_140     D_141  D_142     D_143     D_144  \
# 0    NaN    NaN  0.002426  0.003706  0.003819    NaN  0.000569  0.000610
# 1    NaN    NaN  0.003956  0.003166  0.005032    NaN  0.009575  0.005493
#
#       D_145  target
# 0  0.002674       0
# 1  0.009216       0
#
# [2 rows x 191 columns]

# %% [markdown]
# El conjunto de datos contiene características de perfil agregadas para cada cliente en cada fecha de estado de cuenta. Las features están anonimizadas y normalizadas. Estas se clasifican en las siguientes categorías generales:
#
# * D_* = Variables de morosidad
# * S_* = Variables de gasto
# * P_* = Variables de pago
# * B_* = Variables de balance
# * R_* = Variables de riesgo

# %%
string = str(' '.join((train.columns)))
Delinquency_columns = re.findall(r'(D_\d*)', string)
Spend_columns = re.findall(r'(S_\d*)', string)
Payment_columns = re.findall(r'(P_\d*)', string)
Balance_columns = re.findall(r'(B_\d*)', string)
Risk_Columns = re.findall(r'(R_\d*)', string)

print(f'Hay {len(Delinquency_columns)} variables sobre delincuencia')
print(f'Hay {len(Spend_columns)} variables sobre gastos')
print(f'Hay {len(Payment_columns)} variables sobre pagos')
print(f'Hay {len(Balance_columns)} variables sobre balances')
print(f'Hay {len(Risk_Columns)} variables sobre riesgo')
# Out:
# Hay 96 variables sobre delincuencia
# Hay 22 variables sobre gastos
# Hay 3 variables sobre pagos
# Hay 40 variables sobre balances
# Hay 28 variables sobre riesgo

# %% [markdown]
# Evaluaremos las correlaciones entre variables, y para con el target, de cada uno de los 5 tipos de características.
# Comenzaremos con las características denominadas de "Delincuencia", las cuales son las más numerosas.

# %% [markdown]
# ## Seleccionamos las features de "delincuencia" más relevantes
#
# Nos quedamos con 9 de 96 features

# %%
Delinquency_data = train[Delinquency_columns + ['target']]

# %%
cor_matrix = Delinquency_data.corr().abs()
cor_matrix.target.sort_values()[-15:-2]
# Out:
# D_47    0.280047
# D_43    0.283743
# D_70    0.305350
# D_61    0.322122
# D_77    0.335407
# D_42    0.337734
# D_62    0.352230
# D_74    0.421407
# D_58    0.448642
# D_55    0.456671
# D_75    0.457557
# D_44    0.470412
# D_48    0.549362
# Name: target, dtype: float64

# %%
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.95)]
print(); print(to_drop)
# Out:
# ['D_75', 'D_77', 'D_104', 'D_119', 'D_141', 'D_143']

# %%
selected_d_data = Delinquency_data[['D_47', 'D_43', 'D_70', 'D_61', 'D_42', 'D_62', 'D_74', 'D_44', 'D_48', 'target']]

# %%
cm = selected_d_data.corr().abs()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(8, 8))
    ax = sns.heatmap(correlaciones_Svars, mask=mask, vmax=1, vmin=-1, square=True, annot=True)

# %% [markdown]
# # Seleccionamos las features  de "pagos" relevantes
#
# Nos quedaremos con las 3 variables

# %%
pay_data = train[Payment_columns + ['target']]

# %%
cm = pay_data.corr().abs()
print(cm)
# Out:
#              P_2       P_3       P_4    target
# P_2     1.000000  0.399225  0.278898  0.610765
# P_3     0.399225  1.000000  0.104672  0.243743
# P_4     0.278898  0.104672  1.000000  0.237511
# target  0.610765  0.243743  0.237511  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
mask = np.zeros_like(cm)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 7))
    ax = sns.heatmap(cm, mask=mask, vmax=1, vmin=-1, square=True, annot=True, cmap='coolwarm')

# %% [markdown]
# # Seleccionamos las features  de "balances" relevantes
#
# Nos quedamos con 10 de 40

# %%
balance_data = train[Balance_columns + ['target']]

# %%
cm = balance_data.corr().abs()
print(cm)
# Out:
#              B_1       B_2       B_3       B_4       B_5       B_6       B_7  \
# B_1     1.000000  0.631075  0.729889  0.497810  0.055300  0.042160  0.633427
# B_2     0.631075  1.000000  0.713539  0.510442  0.098170  0.057862  0.591253
# B_3     0.729889  0.713539  1.000000  0.548815  0.052577  0.047736  0.627605
# B_4     0.497810  0.510442  0.548815  1.000000  0.004404  0.055743  0.691608
# B_5     0.055300  0.098170  0.052577  0.004404  1.000000  0.009241  0.089521
# B_6     0.042160  0.057862  0.047736  0.055743  0.009241  1.000000  0.060999
# B_7     0.633427  0.591253  0.627605  0.691608  0.089521  0.060999  1.000000
# B_8     0.130491  0.205662  0.095839  0.084535  0.077077  0.011408  0.123252
# B_9     0.543258  0.613926  0.536883  0.421208  0.049727  0.041805  0.473465
# B_10    0.020018  0.028597  0.022088  0.026117  0.007571  0.028415  0.029522
# B_11    0.995574  0.604082  0.718244  0.496639  0.048059  0.040074  0.614518
# B_12    0.036642  0.053007  0.032444  0.031892  0.578085  0.009229  0.055232
# B_13    0.026937  0.060700  0.038201  0.042977  0.592558  0.015216  0.066977
# B_14    0.232873  0.168381  0.215651  0.306679  0.441361  0.011779  0.102250
# B_15    0.016615  0.023018  0.057185  0.172209  0.465823  0.002301  0.014782
# B_16    0.585276  0.774867  0.724134  0.531455  0.047759  0.061913  0.557867
# B_17    0.402008  0.683953  0.469408  0.328335  0.068695  0.068127  0.390543
# B_18    0.571484  0.849712  0.652224  0.656930  0.064283  0.080398  0.665188
# B_19    0.715678  0.628372  0.789322  0.473743  0.065471  0.044663  0.621030
# B_20    0.625322  0.788000  0.764262  0.547751  0.051473  0.053697  0.588741
# B_21    0.102671  0.074305  0.050277  0.037202  0.010422  0.004478  0.062727
# B_22    0.621643  0.640894  0.750389  0.496251  0.044397  0.041058  0.514241
# B_23    0.635436  0.584502  0.634765  0.728607  0.082742  0.059382  0.995051
# B_24    0.043381  0.052439  0.054786  0.055584  0.019941  0.005272  0.036861
# B_25    0.525343  0.356308  0.396393  0.367123  0.058802  0.023424  0.278234
# B_23    0.032087  0.634005  0.277203  0.035492  0.027864  0.127034  0.423175
# B_24    0.012153  0.043008  0.005501  0.002257  0.470472  0.028734  0.109031
# B_25    0.212242  0.513869  0.371350  0.004426  0.039061  0.025538  0.185858
# B_26    0.002185  0.003127  0.006446  0.000021  0.021159  0.064254  0.019853
# B_27    0.000040  0.000019  0.004688  0.000351  0.003841  0.002130  0.003223
# B_28    0.079210  0.340518  0.116619  0.016592  0.038988  0.001386  0.225442
# B_29    0.017287  0.005100  0.022605  0.014468  0.025670  0.045525  0.072445
# B_31    0.005218  0.029635  0.013901  0.000954  0.106536  0.012589  0.060364
# B_32    0.007754  0.142639  0.006059  0.004649  0.004494  0.026817  0.102256
# B_33    0.016348  0.568063  0.057899  0.013444  0.064996  0.131856  0.452972
# B_36    1.000000  0.007577  0.508236  0.000261  0.005677  0.024945  0.044677
# B_37    0.007577  1.000000  0.060726  0.012436  0.032725  0.096509  0.387133
# B_39    0.508236  0.060726  1.000000  0.011013  0.017724  0.214397  0.093300
# B_40    0.000261  0.012436  0.011013  1.000000  0.001850  0.083724  0.014906
# B_41    0.005677  0.032725  0.017724  0.001850  1.000000  0.024806  0.093700
# B_42    0.024945  0.096509  0.214397  0.083724  0.024806  1.000000  0.117707
# target  0.044677  0.387133  0.093300  0.014906  0.093700  0.117707  1.000000
#
# [39 rows x 39 columns]

# %%
mask = np.zeros_like(cm)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(15, 15))
    ax = sns.heatmap(cm, mask=mask, vmax=1, vmin=-1, square=True, cmap='coolwarm')

# %%
cm.target.sort_values()[-15:-2]
# Out:
# B_22    0.369805
# B_20    0.382825
# B_37    0.387133
# B_19    0.388499
# B_1     0.389767
# B_16    0.396620
# B_4     0.403586
# B_23    0.423175
# B_3     0.429695
# B_7     0.430917
# B_33    0.452972
# B_9     0.475858
# B_2     0.483062
# Name: target, dtype: float64

# %%
selected_balance_data = balance_data[['B_2', 'B_9', 'B_33', 'B_7', 'B_3', 'B_23', 'B_4', 'B_16', 'B_1',
                                        'B_19', 'B_37', 'B_20', 'B_22', 'target']]

# %%
upper_tri = cm.where(np.triu(np.ones(cm.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.89)]
print(); print(to_drop)
# Out:
# ['B_11', 'B_15', 'B_23', 'B_33', 'B_37']

# %%
selected_balance_data = selected_balance_data.drop(columns=['B_33', 'B_23', 'B_20', 'B_37'])

# %%
cm = selected_balance_data.corr().abs()

# %%
mask = np.zeros_like(cm)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(8, 8))
    ax = sns.heatmap(cm, mask=mask, vmax=1, vmin=-1, square=True, annot=True, cmap='coolwarm')

# %% [markdown]
# # Seleccionamos las features  de "riesgo" relevantes

# %%
risk_data = train[Risk_Columns + ['target']]

# %%
cm = risk_data.corr().abs()

# %%
mask = np.zeros_like(cm)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(15, 15))
    ax = sns.heatmap(cm, mask=mask, vmax=1, vmin=-1, square=True, cmap='coolwarm')

# %%
cm.target.sort_values()[-15:-2]
# Out:
# R_15    0.129788
# R_16    0.130129
# R_26    0.134221
# R_12    0.135399
# R_24    0.149799
# R_21    0.153407
# R_8     0.154077
# R_5     0.167278
# R_4     0.221091
# R_10    0.234839
# R_2     0.263741
# R_27    0.277071
# R_3     0.286787
# Name: target, dtype: float64

# %%
selected_risk_data = risk_data[['R_3', 'R_27', 'R_2', 'R_10', 'R_4', 'R_5', 'R_8', 'R_21', 'target']]

# %%
upper_tri = cm.where(np.triu(np.ones(cm.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.89)]
print(); print(to_drop)
# Out:
# []

# %%
cm = selected_risk_data.corr().abs()
print(cm)
# Out:
#              R_3      R_27       R_2      R_10       R_4       R_5       R_8  \
# R_3     1.000000  0.246154  0.066792  0.116834  0.054356  0.046527  0.048476
# R_27    0.246154  1.000000  0.117817  0.121105  0.094912  0.081498  0.071142
# R_2     0.066792  0.117817  1.000000  0.189535  0.778281  0.546804  0.517588
# R_10    0.116834  0.121105  0.189535  1.000000  0.199040  0.199836  0.211147
# R_4     0.054356  0.094912  0.778281  0.199040  1.000000  0.672136  0.626703
# R_5     0.046527  0.081498  0.546804  0.199836  0.672136  1.000000  0.791508
# R_8     0.048476  0.071142  0.517588  0.211147  0.626703  0.791508  1.000000
# R_21    0.081862  0.070921  0.043969  0.063841  0.041039  0.030553  0.030722
# target  0.286787  0.277071  0.263741  0.234839  0.221091  0.167278  0.154077
#
#             R_21    target
# R_3     0.081862  0.286787
# R_27    0.070921  0.277071
# R_2     0.043969  0.263741
# R_10    0.063841  0.234839
# R_4     0.041039  0.221091
# R_5     0.030553  0.167278
# R_8     0.030722  0.154077
# R_21    1.000000  0.153407
# target  0.153407  1.000000

# %%
mask = np.zeros_like(cm)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(8, 8))
    ax = sns.heatmap(cm, mask=mask, vmax=1, vmin=-1, square=True, annot=True, cmap='coolwarm')

# %%
selected_risk_data = selected_risk_data.drop(columns=['R_4', 'R_8', 'R_5'])

cm = selected_risk_data.corr().abs()

mask = np.zeros_like(cm)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(8, 8))
    ax = sns.heatmap(cm, mask=mask, vmax=1, vmin=-1, square=True, annot=True, cmap='coolwarm')

# %% [markdown]
# # Agrupamos la data seleccionada en un nuevo dataframe

# %%
df_init = train[['customer_ID','S_2']]
df_delincuency = selected_d_data.drop(columns=['target'])
df_spend = selected_spend_data.drop(columns=['target'])
df_balance = selected_balance_data.drop(columns=['target'])
df_pay = train[Payment_columns]
df = pd.concat([df_init, df_delincuency, df_spend, df_pay, df_balance, selected_risk_data], axis=1)
df
# Out:
#                                                customer_ID        S_2  \
# 0        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-03-09
# 1        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-04-07
# 2        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-05-28
# 3        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-06-13
# 4        0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f... 2017-07-16
# ...                                                    ...        ...
# 5531446  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2017-11-05
# 5531447  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2017-12-23
# 5531448  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-01-06
# 5531449  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-02-06
# 5531450  fffff1d38b785cef84adeace64f8f83db3a0c31e8d92ea... 2018-03-14
#
#              D_47      D_43      D_70      D_61  D_42      D_62      D_74  \
# 0        0.525391       NaN  0.008339  0.308350   NaN  0.091064  0.080444
# 1        0.521484       NaN  0.006523  0.265137   NaN  0.086792  0.081421
# 2        0.524414       NaN  0.002615  0.212158   NaN  0.093994  0.078918
# 3        0.530762       NaN  0.002052  0.204346   NaN  0.094849  0.077515
# 4        0.529297       NaN  0.001419  0.175659   NaN  0.093933  0.076538
# ...           ...       ...       ...       ...   ...       ...       ...
# 5531446  0.530762  0.014229  0.003292  0.005295   NaN  0.324951  0.009697
# 5531447  0.534668  0.009468  0.004383  0.018173   NaN  0.328613  0.007172
# 5531448  0.530273  0.006592  0.006802  0.013031   NaN  0.328857  0.006229
# 5531449  0.531250  0.014236  0.004192  0.032196   NaN  0.330811  0.004906
# 5531450  0.531738  0.013458  0.258301 -0.003555   NaN  0.078857  0.080322
#
#              D_44  ...      B_16       B_1      B_19      B_22       R_3  \
# 0        0.000630  ...  0.007664  0.008728  0.008522  0.004807  0.001423
# 1        0.002525  ...  0.007149  0.004925  0.002237  0.001283  0.001984
# 2        0.007607  ...  0.003637  0.021652  0.000408  0.009392  0.007427
# 3        0.006405  ...  0.005894  0.013687  0.005898  0.004555  0.003515
# 4        0.007732  ...  0.001715  0.015190  0.007774  0.000104  0.001362
# ...           ...  ...       ...       ...       ...       ...       ...
# 5531446  0.002178  ...  0.835938  0.020813  0.003550  0.002443  0.002056
# 5531447  0.005219  ...  0.754883  0.007210  0.001557  0.005238  0.002460
# 5531448  0.002350  ...  0.757812  0.013153  0.000679  0.006931  0.009697
# 5531449  0.006508  ...  0.671875  0.009857  0.002403  0.005150  0.005722
# 5531450  0.006794  ...  0.583984  0.000077  0.008171  0.008720  0.005016
#
#              R_27       R_2      R_10      R_21  target
# 0        1.008789  0.006203  0.007122  0.002449       0
# 1        1.002930  0.006207  0.005966  0.002247       0
# 2        1.000977  0.003260  0.005447  0.007793       0
# 3        1.004883  0.009918  0.001888  0.007687       0
# 4        1.002930  0.006668  0.006111  0.009659       0
# ...           ...       ...       ...       ...     ...
# 5531446  1.009766  0.002472  0.006989  0.002718       0
# 5531447  1.007812  0.008720  0.005150  0.002911       0
# 5531448  1.003906  0.008369  0.006420  0.000365       0
# 5531449  1.001953  0.004704  0.000041  0.007687       0
# 5531450  1.004883  0.001016  0.004124  0.005943       0
#
# [5531451 rows x 33 columns]

# %%
cm = df.corr().abs()

# %%
mask = np.zeros_like(cm)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(20, 20))
    ax = sns.heatmap(cm, mask=mask, vmax=1, vmin=-1, annot = True, cmap='coolwarm')

# %%
cm.target.sort_values()[-20:-1]
# Out:
# R_3     0.286787
# D_70    0.305350
# D_61    0.322122
# S_7     0.334606
# D_42    0.337734
# D_62    0.352230
# B_22    0.369805
# B_19    0.388499
# B_1     0.389767
# B_16    0.396620
# B_4     0.403586
# D_74    0.421407
# B_3     0.429695
# B_7     0.430917
# D_44    0.470412
# B_9     0.475858
# B_2     0.483062
# D_48    0.549362
# P_2     0.610765
# Name: target, dtype: float64

# %%
upper_tri = cm.where(np.triu(np.ones(cm.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.90)]
print(); print(to_drop)
# Out:
# []

# %%
df.to_csv('/Users/usuario/workspace/AMEX_data/train_data_transformed.csv')
